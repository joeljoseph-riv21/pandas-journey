# %% [markdown]
# *Writing code to practice **EDA and data cleaning** by working with dropna()& fillna() methods*

# %%
import kagglehub
path = kagglehub.dataset_download("benroshan/factors-affecting-campus-placement")
# Out:
# Using Colab cache for faster access to the 'factors-affecting-campus-placement' dataset.

# %%
import os
for root, _, filename in os.walk(path):
    for files in filename:
        print(f"filename:{files}")

        file_path= os.path.join(root, files)
        print(f"file_path:{file_path}")
# Out:
# filename:Placement_Data_Full_Class.csv
# file_path:/kaggle/input/factors-affecting-campus-placement/Placement_Data_Full_Class.csv

# %%
import pandas as pd
df= pd.read_csv(file_path)
print(df.shape)
# Out:
# (215, 15)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB
# None

# %%
print(df.head())
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
print(df.describe(include='all'))
# Out:
#              sl_no gender       ssc_p    ssc_b       hsc_p   hsc_b     hsc_s  \
# count   215.000000    215  215.000000      215  215.000000     215       215
# unique         NaN      2         NaN        2         NaN       2         3
# top            NaN      M         NaN  Central         NaN  Others  Commerce
# freq           NaN    139         NaN      116         NaN     131       113
# mean    108.000000    NaN   67.303395      NaN   66.333163     NaN       NaN
# std      62.209324    NaN   10.827205      NaN   10.897509     NaN       NaN
# min       1.000000    NaN   40.890000      NaN   37.000000     NaN       NaN
# 25%      54.500000    NaN   60.600000      NaN   60.900000     NaN       NaN
# 50%     108.000000    NaN   67.000000      NaN   65.000000     NaN       NaN
# 75%     161.500000    NaN   75.700000      NaN   73.000000     NaN       NaN
# max     215.000000    NaN   89.400000      NaN   97.700000     NaN       NaN
#
# ...

# %%
print(df.isnull().sum())
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
groups= df.groupby(['salary'])
grouped= groups.min()
print(grouped.iloc[0:13,9:15])
# Out:
#          workex  etest_p specialisation  mba_p  status
# salary
# 200000.0     No    55.60        Mkt&Fin  62.98  Placed
# 204000.0     No    70.00        Mkt&Fin  54.55  Placed
# 210000.0     No    58.00        Mkt&Fin  62.36  Placed
# 216000.0     No    67.00        Mkt&Fin  56.49  Placed
# 218000.0     No    68.00        Mkt&Fin  59.75  Placed
# 220000.0     No    55.00        Mkt&Fin  52.71  Placed
# 225000.0     No    56.00         Mkt&HR  60.41  Placed
# 230000.0     No    61.00        Mkt&Fin  59.47  Placed
# 231000.0     No    91.34        Mkt&Fin  61.29  Placed
# 233000.0     No    85.00         Mkt&HR  55.14  Placed
# 236000.0    Yes    50.48        Mkt&Fin  71.00  Placed
# 240000.0     No    53.70        Mkt&Fin  52.38  Placed
# 250000.0     No    52.00        Mkt&Fin  53.20  Placed

# %%
# fill missing 'salary' values with 0
df_zero = df.copy()
df_zero['salary'] = df_zero['salary'].fillna(0)
print(df_zero[df_zero['status'] == 'Not Placed'].head())
# Out:
#     sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3       4      M   56.0  Central   52.0  Central   Science     52.00
# 5       6      M   55.0   Others   49.8   Others   Science     67.25
# 6       7      F   46.0   Others   49.2   Others  Commerce     79.00
# 9      10      M   58.0  Central   70.0  Central  Commerce     61.00
# 12     13      F   47.0  Central   55.0   Others   Science     65.00
#
#      degree_t workex  etest_p specialisation  mba_p      status  salary
# 3    Sci&Tech     No    66.00         Mkt&HR  59.43  Not Placed     0.0
# 5    Sci&Tech    Yes    55.00        Mkt&Fin  51.58  Not Placed     0.0
# 6   Comm&Mgmt     No    74.28        Mkt&Fin  53.29  Not Placed     0.0
# 9   Comm&Mgmt     No    54.00        Mkt&Fin  52.21  Not Placed     0.0
# 12  Comm&Mgmt     No    62.00         Mkt&HR  65.04  Not Placed     0.0

# %%
# the count of missing values in the 'salary' column
print(df['salary'].isnull().sum())
# Out:
# 67

# %%
# fill missing 'salary' values with the mean
# calculate the mean salary of placed students
mean_salary= df[df['status'] == 'Placed']['salary'].mean()

df_mean= df.copy()
df_mean['salary']= df_mean['salary'].fillna(mean_salary)
print(df_mean[df_mean['status'] == 'Not Placed'].head())
# Out:
#     sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3       4      M   56.0  Central   52.0  Central   Science     52.00
# 5       6      M   55.0   Others   49.8   Others   Science     67.25
# 6       7      F   46.0   Others   49.2   Others  Commerce     79.00
# 9      10      M   58.0  Central   70.0  Central  Commerce     61.00
# 12     13      F   47.0  Central   55.0   Others   Science     65.00
#
#      degree_t workex  etest_p specialisation  mba_p      status         salary
# 3    Sci&Tech     No    66.00         Mkt&HR  59.43  Not Placed  288655.405405
# 5    Sci&Tech    Yes    55.00        Mkt&Fin  51.58  Not Placed  288655.405405
# 6   Comm&Mgmt     No    74.28        Mkt&Fin  53.29  Not Placed  288655.405405
# 9   Comm&Mgmt     No    54.00        Mkt&Fin  52.21  Not Placed  288655.405405
# 12  Comm&Mgmt     No    62.00         Mkt&HR  65.04  Not Placed  288655.405405

# %%
# drop rows where 'salary' is NaN
df_drop= df.copy()
df_drop= df_drop.dropna(subset=['salary'])

print(f"original number of rows: {df.shape[0]}")
print(f"number of rows after dropping: {df_drop.shape[0]}")
# Out:
# original number of rows: 215
# number of rows after dropping: 148
